# %%
# %matplotlib notebook
import sys
sys.path.insert(0, '..')


import matplotlib.pyplot as plt
import dataframe_manip as hp
import pandas as pd

# %%
data = hp.csv_to_dataframe('../wifi_data_until_20190204.csv')

# %%
data.plot(y='POM-SCC015-AP205-23')
# Out:
# <img src="data:image/png;base64,..." width="640">
