# %%
# %matplotlib notebook
import sys
sys.path.insert(0, '..')


import matplotlib.pyplot as plt
import dataframe_manip as hp
import pandas as pd

# %%
data = hp.csv_to_dataframe('../wifi_data_until_20190204.csv')
building = hp.get_hourly_data_building(data, 'SCC')

# %%
building.plot()
# Out:
# <img src="data:image/png;base64,..." width="885">
# /anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)
